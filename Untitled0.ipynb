# %% [markdown]
# <a href="https://colab.research.google.com/github/Hadiyev/yolo_colab/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
# !ls -la "/content/gdrive/My Drive/darknet"
cwd = os.getcwd()
print(cwd)
# Out:
# total 3151
# -rw------- 1 root root 3221752 May 18 16:38 compiled
# drwx------ 2 root root    4096 May 18 13:28 cuDNN
# /content

# %%
# We're unzipping the cuDNN files from your Drive folder directly to the VM CUDA folders
# !tar -xzvf gdrive/My\ Drive/darknet/cuDNN/cudnn-10.0-linux-x64-v7.5.0.56.solitairetheme8 -C /usr/local/
# !chmod a+r /usr/local/cuda/include/cudnn.h
# Out:
# cuda/include/cudnn.h
# cuda/NVIDIA_SLA_cuDNN_Support.txt
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.7
# cuda/lib64/libcudnn.so.7.5.0
# cuda/lib64/libcudnn_static.a
# #define CUDNN_MAJOR 7
# #define CUDNN_MINOR 5
# #define CUDNN_PATCHLEVEL 0
# --
# #define CUDNN_VERSION (CUDNN_MAJOR * 1000 + CUDNN_MINOR * 100 + CUDNN_PATCHLEVEL)
#
# #include "driver_types.h"

# %%
# Leave this code uncommented on the very first run of your notebook or if you ever need to recompile darknet again.
# Comment this code on the future runs.
# !git clone https://github.com/kriyeng/darknet/
# %cd darknet

# Check the folder
# !ls

# I have a branch where I have done the changes commented above
# !git checkout feature/google-colab

#Compile Darknet
# !make
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10068, done.
# remote: Total 10068 (delta 0), reused 0 (delta 0), pack-reused 10068
# Receiving objects: 100% (10068/10068), 10.04 MiB | 19.59 MiB/s, done.
# Resolving deltas: 100% (6736/6736), done.
# /content/darknet
# 3rdparty      CMakeLists.txt	      image_yolov3.sh	     scripts
# appveyor.yml  CMakeSettings.json      include		     src
# build	      DarknetConfig.cmake.in  json_mjpeg_streams.sh  video_v2.sh
# build.ps1     darknet.py	      LICENSE		     video_yolov3.sh
# build.sh      darknet_video.py	      Makefile
# cfg	      data		      net_cam_v3.sh
# cmake	      image_yolov2.sh	      README.md
# Branch 'feature/google-colab' set up to track remote branch 'feature/google-colab' from 'origin'.
# Switched to a new branch 'feature/google-colab'
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(mat_cv*, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:896:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:228:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:475:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2016:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2015:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘get_cuda_stream’:
# ./src/dark_cuda.c:120:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/dark_cuda.c:141:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/dark_cuda.c: In function ‘cudnn_handle’:
# ./src/dark_cuda.c:161:23: warning: unused variable ‘status’ [-Wunused-variable]
#          cudnnStatus_t status = cudnnSetStream(handle[i], get_cuda_stream());
#                        ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:951:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# ./src/maxpool_layer.c: In function ‘cudnn_maxpool_setup’:
# ./src/maxpool_layer.c:26:19: warning: variable ‘maxpool_status’ set but not used [-Wunused-but-set-variable]
#      cudnnStatus_t maxpool_status;
#                    ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:511:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:335:11: warning: unused variable ‘one’ [-Wunused-variable]
#      float one = 1;    // alpha[0], beta[0]
#            ^~~
# ./src/connected_layer.c:333:13: warning: unused variable ‘c’ [-Wunused-variable]
#      float * c = l.output_gpu;
#              ^
# ./src/connected_layer.c:332:13: warning: unused variable ‘b’ [-Wunused-variable]
#      float * b = l.weights_gpu;
#              ^
# ./src/connected_layer.c:331:13: warning: unused variable ‘a’ [-Wunused-variable]
#      float * a = state.input;
#              ^
# ./src/connected_layer.c:330:9: warning: unused variable ‘n’ [-Wunused-variable]
#      int n = l.outputs;
#          ^
# ./src/connected_layer.c:329:9: warning: unused variable ‘k’ [-Wunused-variable]
#      int k = l.inputs;
#          ^
# ./src/connected_layer.c:328:9: warning: unused variable ‘m’ [-Wunused-variable]
#      int m = l.batch;
#          ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:874:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1008:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1007:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:58:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:65:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:92:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:101:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:40,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu:125:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1178:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++
# cp: cannot create regular file '/content/gdrive/My Drive/darknet/bin/darknet': No such file or directory

# %%
#Copies the Darknet compiled version to Google drive
# !cp ./darknet /content/gdrive/My\ Drive/darknet/compiled

# %%
# Uncomment after the first run, when you have a copy of compiled darkent in your Google Drive

# Makes a dir for darknet and move there
#!mkdir darknet
#%cd darknet

# Copy the Darkent compiled version to the VM local drive
#!cp /content/gdrive/My\ Drive/darknet/bin/darknet ./darknet

# Set execution permissions to Darknet
#!chmod +x ./darknet

# %%
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
# %cd darknet
# Not necessary cell
# Get yolov3 weights
# !wget https://pjreddie.com/media/files/yolov3.weights
  

# Not necessary cell
# Execute darknet using YOLOv3 model with pre-trained weights to detect objects on 'person.jpg'
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/person.jpg -dont-show

# Show the result using the helper imgShow()
imShow('predictions.jpg')
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# --2019-05-18 17:07:57--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights.1’
#
# yolov3.weights.1    100%[===================>] 236.52M  42.4MB/s    in 6.0s
#
# 2019-05-18 17:08:03 (39.6 MB/s) - ‘yolov3.weights.1’ saved [248007048/248007048]
#
# layer     filters    size              input                output
#    0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32 0.299 BF
#    1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64 1.595 BF
#    2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32 0.177 BF
#    3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128 1.595 BF
#    6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#    7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64 0.177 BF
#   10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
#   12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256 1.595 BF
#   13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12
#   16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15
#   19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18
#   22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21
#   25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24
#   28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27
#   31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30
#   34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#   35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33
#   37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512 1.595 BF
#   38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37
#   41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40
#   44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43
#   47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46
#   50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49
#   53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52
#   56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55
#   59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58
#   62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024 1.595 BF
#   63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62
#   66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65
#   69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68
#   72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71
#   75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512 0.177 BF
#   80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   81 conv    255  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 255 0.088 BF
#   82 yolo
#   83 route  79
#   84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256 0.044 BF
#   85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#   86 route  85 61
#   87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256 0.266 BF
#   88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256 0.177 BF
#   92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512 1.595 BF
#   93 conv    255  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 255 0.177 BF
#   94 yolo
#   95 route  91
#   96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128 0.044 BF
#   97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#   98 route  97 36
#   99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128 0.266 BF
#  100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128 0.177 BF
#  104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256 1.595 BF
#  105 conv    255  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 255 0.353 BF
#  106 yolo
# Total BFLOPS 65.864
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from yolov3.weights...
#  seen 64
# Done!
# data/person.jpg: Predicted in 41.709000 milli-seconds.
# dog: 99%
# person: 100%
# horse: 100%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:3717): Gtk-WARNING **: 17:08:09.218: cannot open display:

# %%
# !./darknet detector train "/content/gdrive/My Drive/darknet/obj.data" "/content/gdrive/My Drive/darknet/yolov3-tiny.cfg" "/content/gdrive/My Drive/darknet/darknet53.conv.74" -dont_show
# Out:
# yolov3-tiny
# layer     filters    size              input                output
#    0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16 0.150 BF
#    1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16 0.003 BF
#    2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32 0.399 BF
#    3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32 0.001 BF
#    4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64 0.399 BF
#    5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64 0.001 BF
#    6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128 0.399 BF
#    7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128 0.000 BF
#    8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256 0.399 BF
#    9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256 0.000 BF
#   10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   11 max          2 x 2 / 1    13 x  13 x 512   ->    13 x  13 x 512 0.000 BF
#   12 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   13 conv    256  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 256 0.089 BF
#   14 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   15 conv     18  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x  18 0.003 BF
#   16 yolo
#   17 route  13
#   18 conv    128  1 x 1 / 1    13 x  13 x 256   ->    13 x  13 x 128 0.011 BF
#   19 upsample            2x    13 x  13 x 128   ->    26 x  26 x 128
#   20 route  19 8
#   21 conv    256  3 x 3 / 1    26 x  26 x 384   ->    26 x  26 x 256 1.196 BF
#   22 conv     18  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x  18 0.006 BF
#   23 yolo
# Total BFLOPS 5.448
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from /content/gdrive/My Drive/darknet/darknet53.conv.74...
#  seen 64
# Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.710480 seconds
#
#  1: 676.995667, 676.995667 avg loss, 0.000000 rate, 1.714426 seconds, 64 images
# Loaded: 0.000050 seconds
#
#  2: 676.703186, 676.966431 avg loss, 0.000000 rate, 1.666459 seconds, 128 images
# Loaded: 0.000033 seconds
#
#  3: 677.020691, 676.971863 avg loss, 0.000000 rate, 1.651569 seconds, 192 images
# Loaded: 0.000044 seconds
#
#  4: 676.892395, 676.963928 avg loss, 0.000000 rate, 1.645278 seconds, 256 images
# Loaded: 0.000043 seconds
#
#  5: 677.221680, 676.989685 avg loss, 0.000000 rate, 1.654702 seconds, 320 images
# Loaded: 0.000033 seconds
#
#  6: 676.707031, 676.961426 avg loss, 0.000000 rate, 1.677713 seconds, 384 images
# Loaded: 0.000038 seconds
#
#  7: 676.893738, 676.954651 avg loss, 0.000000 rate, 1.659983 seconds, 448 images
# Loaded: 0.000033 seconds
#
#  8: 676.819824, 676.941162 avg loss, 0.000000 rate, 1.687473 seconds, 512 images
# Loaded: 0.000038 seconds
#
#  9: 677.058350, 676.952881 avg loss, 0.000000 rate, 1.667883 seconds, 576 images
# Loaded: 0.000039 seconds
#
#  10: 676.981262, 676.955688 avg loss, 0.000000 rate, 1.686251 seconds, 640 images
# Resizing
# 320 x 320
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.500195 seconds
#
#  11: 189.757294, 628.235840 avg loss, 0.000000 rate, 0.617214 seconds, 704 images
# Loaded: 0.041739 seconds
#
#  12: 189.791534, 584.391418 avg loss, 0.000000 rate, 0.620998 seconds, 768 images
# Loaded: 0.020668 seconds
#
#  13: 190.002060, 544.952454 avg loss, 0.000000 rate, 0.617205 seconds, 832 images
# Loaded: 0.020460 seconds
#
#  14: 189.892883, 509.446503 avg loss, 0.000000 rate, 0.605393 seconds, 896 images
# Loaded: 0.054747 seconds
#
#  15: 190.121796, 477.514038 avg loss, 0.000000 rate, 0.585693 seconds, 960 images
# Loaded: 0.053408 seconds
#
#  16: 189.781189, 448.740753 avg loss, 0.000000 rate, 0.628951 seconds, 1024 images
# Loaded: 0.020111 seconds
#
#  17: 190.035049, 422.870178 avg loss, 0.000000 rate, 0.659810 seconds, 1088 images
# Loaded: 0.000032 seconds
#
#  18: 189.767334, 399.559906 avg loss, 0.000000 rate, 0.608479 seconds, 1152 images
# Loaded: 0.033287 seconds
#
#  19: 189.536575, 378.557587 avg loss, 0.000000 rate, 0.606298 seconds, 1216 images
# Loaded: 0.039360 seconds
#
#  20: 189.908249, 359.692657 avg loss, 0.000000 rate, 0.608127 seconds, 1280 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.501619 seconds
#
#  21: 228.983932, 346.621796 avg loss, 0.000000 rate, 0.670782 seconds, 1344 images
# Loaded: 0.021006 seconds
#
#  22: 229.490860, 334.908691 avg loss, 0.000000 rate, 0.675714 seconds, 1408 images
# Loaded: 0.000202 seconds
#
#  23: 228.754608, 324.293274 avg loss, 0.000000 rate, 0.665355 seconds, 1472 images
# Loaded: 0.004212 seconds
#
#  24: 229.026962, 314.766632 avg loss, 0.000000 rate, 0.666909 seconds, 1536 images
# Loaded: 0.022005 seconds
#
#  25: 228.992096, 306.189178 avg loss, 0.000000 rate, 0.663993 seconds, 1600 images
# Loaded: 0.013073 seconds
#
#  26: 228.975616, 298.467834 avg loss, 0.000000 rate, 0.659047 seconds, 1664 images
# Loaded: 0.011416 seconds
#
#  27: 228.848312, 291.505890 avg loss, 0.000000 rate, 0.674081 seconds, 1728 images
# Loaded: 0.015261 seconds
#
#  28: 229.253021, 285.280609 avg loss, 0.000000 rate, 0.683296 seconds, 1792 images
# Loaded: 0.027316 seconds
#
#  29: 229.157425, 279.668304 avg loss, 0.000000 rate, 0.655421 seconds, 1856 images
# Loaded: 0.011908 seconds
#
#  30: 228.922287, 274.593689 avg loss, 0.000000 rate, 0.668644 seconds, 1920 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.612629 seconds
#
#  31: 423.201385, 289.454468 avg loss, 0.000000 rate, 1.138660 seconds, 1984 images
# Loaded: 0.000058 seconds
#
#  32: 423.130646, 302.822083 avg loss, 0.000000 rate, 1.132394 seconds, 2048 images
# Loaded: 0.000044 seconds
#
#  33: 423.037506, 314.843628 avg loss, 0.000000 rate, 1.152881 seconds, 2112 images
# Loaded: 0.000044 seconds
#
#  34: 423.022125, 325.661469 avg loss, 0.000000 rate, 1.108961 seconds, 2176 images
# Loaded: 0.000039 seconds
#
#  35: 423.243134, 335.419647 avg loss, 0.000000 rate, 1.169539 seconds, 2240 images
# Loaded: 0.000037 seconds
#
#  36: 423.008759, 344.178558 avg loss, 0.000000 rate, 1.158906 seconds, 2304 images
# Loaded: 0.000035 seconds
#
#  37: 423.023041, 352.063019 avg loss, 0.000000 rate, 1.131070 seconds, 2368 images
# Loaded: 0.000036 seconds
#
#  38: 422.938202, 359.150543 avg loss, 0.000000 rate, 1.134260 seconds, 2432 images
# Loaded: 0.000033 seconds
#
#  39: 423.040680, 365.539551 avg loss, 0.000000 rate, 1.160552 seconds, 2496 images
# Loaded: 0.000032 seconds
#
#  40: 422.817230, 371.267334 avg loss, 0.000000 rate, 1.144779 seconds, 2560 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.563267 seconds
#
#  41: 272.073303, 361.347931 avg loss, 0.000000 rate, 0.743358 seconds, 2624 images
# Loaded: 0.006793 seconds
#
#  42: 271.831177, 352.396240 avg loss, 0.000000 rate, 0.755294 seconds, 2688 images
# Loaded: 0.000033 seconds
#
#  43: 271.815613, 344.338165 avg loss, 0.000000 rate, 0.756102 seconds, 2752 images
# Loaded: 0.000035 seconds
#
#  44: 271.890930, 337.093445 avg loss, 0.000000 rate, 0.744920 seconds, 2816 images
# Loaded: 0.000034 seconds
#
#  45: 271.615936, 330.545685 avg loss, 0.000000 rate, 0.764140 seconds, 2880 images
# Loaded: 0.000033 seconds
#
#  46: 271.815002, 324.672607 avg loss, 0.000000 rate, 0.746571 seconds, 2944 images
# Loaded: 0.000034 seconds
#
#  47: 271.927002, 319.398041 avg loss, 0.000000 rate, 0.745857 seconds, 3008 images
# Loaded: 0.000034 seconds
#
#  48: 271.815735, 314.639801 avg loss, 0.000000 rate, 0.747825 seconds, 3072 images
# Loaded: 0.001918 seconds
#
#  49: 271.620880, 310.337921 avg loss, 0.000000 rate, 0.746253 seconds, 3136 images
# Loaded: 0.000032 seconds
#
#  50: 271.754639, 306.479584 avg loss, 0.000000 rate, 0.761995 seconds, 3200 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.625010 seconds
#
#  51: 228.869324, 298.718567 avg loss, 0.000000 rate, 0.667238 seconds, 3264 images
# Loaded: 0.142539 seconds
#
#  52: 228.791885, 291.725891 avg loss, 0.000000 rate, 0.718495 seconds, 3328 images
# Loaded: 0.088430 seconds
#
#  53: 229.173767, 285.470673 avg loss, 0.000000 rate, 0.698320 seconds, 3392 images
# Loaded: 0.116828 seconds
#
#  54: 228.941772, 279.817780 avg loss, 0.000000 rate, 0.653702 seconds, 3456 images
# Loaded: 0.137484 seconds
#
#  55: 228.979889, 274.733978 avg loss, 0.000000 rate, 0.670186 seconds, 3520 images
# Loaded: 0.135676 seconds
#
#  56: 228.982834, 270.158875 avg loss, 0.000000 rate, 0.742693 seconds, 3584 images
# Loaded: 0.060914 seconds
#
#  57: 228.905624, 266.033539 avg loss, 0.000000 rate, 0.695744 seconds, 3648 images
# Loaded: 0.100406 seconds
#
#  58: 229.193100, 262.349487 avg loss, 0.000000 rate, 0.691182 seconds, 3712 images
# Loaded: 0.111833 seconds
#
#  59: 228.818161, 258.996368 avg loss, 0.000000 rate, 0.708103 seconds, 3776 images
# Loaded: 0.085369 seconds
#
#  60: 229.095093, 256.006226 avg loss, 0.000000 rate, 0.721643 seconds, 3840 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.832333 seconds
#
#  61: 607.747864, 291.180389 avg loss, 0.000000 rate, 1.566265 seconds, 3904 images
# Loaded: 0.000037 seconds
#
#  62: 607.638672, 322.826233 avg loss, 0.000000 rate, 1.567878 seconds, 3968 images
# Loaded: 0.000036 seconds
#
#  63: 607.258972, 351.269501 avg loss, 0.000000 rate, 1.537698 seconds, 4032 images
# Loaded: 0.000038 seconds
#
#  64: 607.758240, 376.918365 avg loss, 0.000000 rate, 1.554264 seconds, 4096 images
# Loaded: 0.000045 seconds
#
#  65: 607.414856, 399.968018 avg loss, 0.000000 rate, 1.528770 seconds, 4160 images
# Loaded: 0.000034 seconds
#
#  66: 607.770630, 420.748291 avg loss, 0.000000 rate, 1.542531 seconds, 4224 images
# Loaded: 0.000036 seconds
#
#  67: 607.288513, 439.402313 avg loss, 0.000000 rate, 1.551590 seconds, 4288 images
# Loaded: 0.000039 seconds
#
#  68: 607.205017, 456.182587 avg loss, 0.000000 rate, 1.575579 seconds, 4352 images
# Loaded: 0.000036 seconds
#
#  69: 607.211365, 471.285461 avg loss, 0.000000 rate, 1.564348 seconds, 4416 images
# Loaded: 0.000035 seconds
#
#  70: 607.313782, 484.888306 avg loss, 0.000000 rate, 1.547206 seconds, 4480 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.526775 seconds
#
#  71: 271.554230, 463.554901 avg loss, 0.000000 rate, 0.746166 seconds, 4544 images
# Loaded: 0.000030 seconds
#
#  72: 271.720795, 444.371490 avg loss, 0.000000 rate, 0.743457 seconds, 4608 images
# Loaded: 0.000035 seconds
#
#  73: 271.625763, 427.096924 avg loss, 0.000000 rate, 0.740280 seconds, 4672 images
# Loaded: 0.000032 seconds
#
#  74: 271.419403, 411.529175 avg loss, 0.000000 rate, 0.739808 seconds, 4736 images
# Loaded: 0.000037 seconds
#
#  75: 271.503937, 397.526642 avg loss, 0.000000 rate, 0.743889 seconds, 4800 images
# Loaded: 0.000028 seconds
#
#  76: 271.341797, 384.908173 avg loss, 0.000000 rate, 0.737505 seconds, 4864 images
# Loaded: 0.000034 seconds
#
#  77: 271.335876, 373.550934 avg loss, 0.000000 rate, 0.742771 seconds, 4928 images
# Loaded: 0.000031 seconds
#
#  78: 271.796356, 363.375488 avg loss, 0.000000 rate, 0.744084 seconds, 4992 images
# Loaded: 0.000033 seconds
#
#  79: 271.687042, 354.206635 avg loss, 0.000000 rate, 0.754647 seconds, 5056 images
# Loaded: 0.000033 seconds
#
#  80: 271.413025, 345.927277 avg loss, 0.000000 rate, 0.746484 seconds, 5120 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.468193 seconds
#
#  81: 317.622131, 343.096771 avg loss, 0.000000 rate, 0.818255 seconds, 5184 images
# Loaded: 0.000032 seconds
#
#  82: 317.671844, 340.554291 avg loss, 0.000000 rate, 0.834926 seconds, 5248 images
# Loaded: 0.000034 seconds
#
#  83: 317.961731, 338.295044 avg loss, 0.000000 rate, 0.851930 seconds, 5312 images
# Loaded: 0.000034 seconds
#
#  84: 317.860138, 336.251556 avg loss, 0.000000 rate, 0.837084 seconds, 5376 images
# Loaded: 0.000040 seconds
#
#  85: 317.770325, 334.403442 avg loss, 0.000000 rate, 0.840385 seconds, 5440 images
# Loaded: 0.000034 seconds
#
#  86: 317.648193, 332.727905 avg loss, 0.000000 rate, 0.836315 seconds, 5504 images
# Loaded: 0.000033 seconds
#
#  87: 317.479370, 331.203064 avg loss, 0.000000 rate, 0.836407 seconds, 5568 images
# Loaded: 0.000033 seconds
#
#  88: 317.555420, 329.838287 avg loss, 0.000000 rate, 0.829563 seconds, 5632 images
# Loaded: 0.000035 seconds
#
#  89: 317.447784, 328.599243 avg loss, 0.000000 rate, 0.844556 seconds, 5696 images
# Loaded: 0.000035 seconds
#
#  90: 317.351929, 327.474518 avg loss, 0.000000 rate, 0.850735 seconds, 5760 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.528826 seconds
#
#  91: 421.458099, 336.872864 avg loss, 0.000000 rate, 1.142396 seconds, 5824 images
# Loaded: 0.000033 seconds
#
#  92: 421.644836, 345.350067 avg loss, 0.000000 rate, 1.142964 seconds, 5888 images
# Loaded: 0.000039 seconds
#
#  93: 421.495789, 352.964630 avg loss, 0.000000 rate, 1.149582 seconds, 5952 images
# Loaded: 0.000040 seconds
#
#  94: 421.229736, 359.791138 avg loss, 0.000000 rate, 1.083687 seconds, 6016 images
# Loaded: 0.000035 seconds
#
#  95: 421.204926, 365.932526 avg loss, 0.000000 rate, 1.144174 seconds, 6080 images
# Loaded: 0.000051 seconds
#
#  96: 420.871155, 371.426392 avg loss, 0.000000 rate, 1.129634 seconds, 6144 images
# Loaded: 0.000051 seconds
#
#  97: 420.910583, 376.374817 avg loss, 0.000000 rate, 1.119188 seconds, 6208 images
# Loaded: 0.000032 seconds
#
#  98: 420.828949, 380.820221 avg loss, 0.000000 rate, 1.136189 seconds, 6272 images
# Loaded: 0.000038 seconds
#
#  99: 420.395508, 384.777740 avg loss, 0.000000 rate, 1.124326 seconds, 6336 images
# Loaded: 0.000034 seconds
#
#  100: 420.215729, 388.321533 avg loss, 0.000000 rate, 1.104694 seconds, 6400 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.612868 seconds
#
#  101: 316.512878, 381.140656 avg loss, 0.000000 rate, 0.826604 seconds, 6464 images
# Loaded: 0.000026 seconds
#
#  102: 316.563782, 374.682983 avg loss, 0.000000 rate, 0.832856 seconds, 6528 images
# Loaded: 0.000034 seconds
#
#  103: 316.625397, 368.877228 avg loss, 0.000000 rate, 0.839114 seconds, 6592 images
# Loaded: 0.000036 seconds
#
#  104: 316.128540, 363.602356 avg loss, 0.000000 rate, 0.835614 seconds, 6656 images
# Loaded: 0.000036 seconds
#
#  105: 316.003967, 358.842529 avg loss, 0.000000 rate, 0.845481 seconds, 6720 images
# Loaded: 0.000035 seconds
#
#  106: 316.279968, 354.586273 avg loss, 0.000000 rate, 0.892422 seconds, 6784 images
# Loaded: 0.000030 seconds
#
#  107: 315.595306, 350.687164 avg loss, 0.000000 rate, 0.839295 seconds, 6848 images
# Loaded: 0.000035 seconds
#
#  108: 315.779755, 347.196411 avg loss, 0.000000 rate, 0.836929 seconds, 6912 images
# Loaded: 0.000035 seconds
#
#  109: 315.681427, 344.044922 avg loss, 0.000000 rate, 0.845391 seconds, 6976 images
# Loaded: 0.000028 seconds
#
#  110: 315.335388, 341.173981 avg loss, 0.000000 rate, 0.882746 seconds, 7040 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.574134 seconds
#
#  111: 418.548431, 348.911438 avg loss, 0.000000 rate, 1.159410 seconds, 7104 images
# Loaded: 0.000037 seconds
#
#  112: 418.228638, 355.843170 avg loss, 0.000000 rate, 1.128830 seconds, 7168 images
# Loaded: 0.000034 seconds
#
#  113: 417.983154, 362.057159 avg loss, 0.000000 rate, 1.144079 seconds, 7232 images
# Loaded: 0.000034 seconds
#
#  114: 417.897827, 367.641235 avg loss, 0.000000 rate, 1.165853 seconds, 7296 images
# Loaded: 0.000043 seconds
#
#  115: 417.899750, 372.667084 avg loss, 0.000000 rate, 1.141799 seconds, 7360 images
# Loaded: 0.000033 seconds
#
#  116: 417.300110, 377.130371 avg loss, 0.000000 rate, 1.165140 seconds, 7424 images
# Loaded: 0.000043 seconds
#
#  117: 417.085815, 381.125916 avg loss, 0.000000 rate, 1.154297 seconds, 7488 images
# Loaded: 0.000031 seconds
#
#  118: 416.792206, 384.692535 avg loss, 0.000000 rate, 1.193861 seconds, 7552 images
# Loaded: 0.000038 seconds
#
#  119: 416.597443, 387.883026 avg loss, 0.000000 rate, 1.198190 seconds, 7616 images
# Loaded: 0.000037 seconds
#
#  120: 416.160828, 390.710815 avg loss, 0.000000 rate, 1.210396 seconds, 7680 images
# Resizing
# 320 x 320
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.579936 seconds
#
#  121: 186.709961, 370.310730 avg loss, 0.000000 rate, 0.636203 seconds, 7744 images
# Loaded: 0.133832 seconds
#
#  122: 186.692810, 351.948944 avg loss, 0.000000 rate, 0.702120 seconds, 7808 images
# Loaded: 0.083648 seconds
#
#  123: 186.292175, 335.383270 avg loss, 0.000000 rate, 0.687141 seconds, 7872 images
# Loaded: 0.081147 seconds
#
#  124: 186.251358, 320.470093 avg loss, 0.000000 rate, 0.736026 seconds, 7936 images
# Loaded: 0.029317 seconds
#
#  125: 186.289536, 307.052032 avg loss, 0.000000 rate, 0.781723 seconds, 8000 images
# Loaded: 0.000028 seconds
#
#  126: 185.874191, 294.934235 avg loss, 0.000000 rate, 0.732808 seconds, 8064 images
# Loaded: 0.047808 seconds
#
#  127: 185.902283, 284.031036 avg loss, 0.000000 rate, 0.677774 seconds, 8128 images
# Loaded: 0.087682 seconds
#
#  128: 185.659119, 274.193848 avg loss, 0.000000 rate, 0.613023 seconds, 8192 images
# Loaded: 0.145852 seconds
#
#  129: 185.910370, 265.365509 avg loss, 0.000000 rate, 0.734013 seconds, 8256 images
# Loaded: 0.047006 seconds
#
#  130: 185.515198, 257.380493 avg loss, 0.000000 rate, 0.689491 seconds, 8320 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.747972 seconds
#
#  131: 469.602905, 278.602722 avg loss, 0.000000 rate, 1.300438 seconds, 8384 images
# Loaded: 0.000039 seconds
#
#  132: 469.185211, 297.660980 avg loss, 0.000000 rate, 1.311924 seconds, 8448 images
# Loaded: 0.000034 seconds
#
#  133: 468.852173, 314.780090 avg loss, 0.000000 rate, 1.270987 seconds, 8512 images
# Loaded: 0.000043 seconds
#
#  134: 468.621460, 330.164215 avg loss, 0.000000 rate, 1.313328 seconds, 8576 images
# Loaded: 0.000044 seconds
#
#  135: 468.004517, 343.948242 avg loss, 0.000000 rate, 1.212555 seconds, 8640 images
# Loaded: 0.000037 seconds
#
#  136: 467.424683, 356.295898 avg loss, 0.000000 rate, 1.214177 seconds, 8704 images
# Loaded: 0.000036 seconds
#
#  137: 466.814911, 367.347809 avg loss, 0.000000 rate, 1.247150 seconds, 8768 images
# Loaded: 0.000044 seconds
#
#  138: 466.975189, 377.310547 avg loss, 0.000000 rate, 1.226850 seconds, 8832 images
# Loaded: 0.000037 seconds
#
#  139: 465.684265, 386.147919 avg loss, 0.000000 rate, 1.246114 seconds, 8896 images
# Loaded: 0.000035 seconds
#
#  140: 465.047119, 394.037842 avg loss, 0.000000 rate, 1.235990 seconds, 8960 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.730088 seconds
#
#  141: 464.473145, 401.081360 avg loss, 0.000000 rate, 1.217112 seconds, 9024 images
# Loaded: 0.000037 seconds
#
#  142: 463.794464, 407.352661 avg loss, 0.000000 rate, 1.209964 seconds, 9088 images
# Loaded: 0.000029 seconds
#
#  143: 463.306549, 412.948059 avg loss, 0.000000 rate, 1.227522 seconds, 9152 images
# Loaded: 0.000031 seconds
#
#  144: 462.319672, 417.885223 avg loss, 0.000000 rate, 1.239734 seconds, 9216 images
# Loaded: 0.000037 seconds
#
#  145: 461.629333, 422.259644 avg loss, 0.000000 rate, 1.220469 seconds, 9280 images
# Loaded: 0.000038 seconds
#
#  146: 460.840942, 426.117767 avg loss, 0.000000 rate, 1.245938 seconds, 9344 images
# Loaded: 0.000035 seconds
#
#  147: 459.960266, 429.502014 avg loss, 0.000000 rate, 1.190978 seconds, 9408 images
# Loaded: 0.000028 seconds
#
#  148: 459.357147, 432.487518 avg loss, 0.000000 rate, 1.201590 seconds, 9472 images
# Loaded: 0.000041 seconds
#
#  149: 458.585480, 435.097321 avg loss, 0.000000 rate, 1.234819 seconds, 9536 images
# Loaded: 0.000037 seconds
#
#  150: 457.500214, 437.337616 avg loss, 0.000001 rate, 1.241795 seconds, 9600 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.505352 seconds
#
#  151: 217.481018, 415.351959 avg loss, 0.000001 rate, 0.664142 seconds, 9664 images
# Loaded: 0.013331 seconds
#
#  152: 216.975784, 395.514343 avg loss, 0.000001 rate, 0.672559 seconds, 9728 images
# Loaded: 0.005198 seconds
#
#  153: 216.698151, 377.632721 avg loss, 0.000001 rate, 0.677485 seconds, 9792 images
# Loaded: 0.014356 seconds
#
#  154: 216.269958, 361.496460 avg loss, 0.000001 rate, 0.672115 seconds, 9856 images
# Loaded: 0.011203 seconds
#
#  155: 215.621216, 346.908936 avg loss, 0.000001 rate, 0.657010 seconds, 9920 images
# Loaded: 0.033361 seconds
#
#  156: 215.386475, 333.756683 avg loss, 0.000001 rate, 0.695587 seconds, 9984 images
# Loaded: 0.000031 seconds
#
#  157: 214.995316, 321.880554 avg loss, 0.000001 rate, 0.659069 seconds, 10048 images
# Loaded: 0.013990 seconds
#
#  158: 214.733185, 311.165833 avg loss, 0.000001 rate, 0.652188 seconds, 10112 images
# Loaded: 0.021601 seconds
#
#  159: 214.102493, 301.459503 avg loss, 0.000001 rate, 0.651891 seconds, 10176 images
# Loaded: 0.040036 seconds
#
#  160: 213.803604, 292.693909 avg loss, 0.000001 rate, 0.668061 seconds, 10240 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.525942 seconds
#
#  161: 253.308380, 288.755371 avg loss, 0.000001 rate, 0.755650 seconds, 10304 images
# Loaded: 0.000045 seconds
#
#  162: 252.935272, 285.173370 avg loss, 0.000001 rate, 0.748222 seconds, 10368 images
# Loaded: 0.000033 seconds
#
#  163: 252.512665, 281.907288 avg loss, 0.000001 rate, 0.767946 seconds, 10432 images
# Loaded: 0.000033 seconds
#
#  164: 252.004059, 278.916962 avg loss, 0.000001 rate, 0.792264 seconds, 10496 images
# Loaded: 0.000034 seconds
#
#  165: 251.423004, 276.167572 avg loss, 0.000001 rate, 0.783574 seconds, 10560 images
# Loaded: 0.000031 seconds
#
#  166: 250.793060, 273.630127 avg loss, 0.000001 rate, 0.744279 seconds, 10624 images
# Loaded: 0.000035 seconds
#
#  167: 250.234741, 271.290588 avg loss, 0.000001 rate, 0.760814 seconds, 10688 images
# Loaded: 0.000031 seconds
#
#  168: 249.971725, 269.158691 avg loss, 0.000001 rate, 0.768628 seconds, 10752 images
# Loaded: 0.000040 seconds
#
#  169: 249.459091, 267.188721 avg loss, 0.000001 rate, 0.754956 seconds, 10816 images
# Loaded: 0.000033 seconds
#
#  170: 248.964096, 265.366272 avg loss, 0.000001 rate, 0.756359 seconds, 10880 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.641186 seconds
#
#  171: 555.227356, 294.352386 avg loss, 0.000001 rate, 1.549085 seconds, 10944 images
# Loaded: 0.000072 seconds
#
#  172: 553.681091, 320.285248 avg loss, 0.000001 rate, 1.559687 seconds, 11008 images
# Loaded: 0.000037 seconds
#
#  173: 552.229370, 343.479675 avg loss, 0.000001 rate, 1.560952 seconds, 11072 images
# Loaded: 0.000041 seconds
#
#  174: 550.636658, 364.195374 avg loss, 0.000001 rate, 1.557358 seconds, 11136 images
# Loaded: 0.000035 seconds
#
#  175: 548.680664, 382.643890 avg loss, 0.000001 rate, 1.561642 seconds, 11200 images
# Loaded: 0.000053 seconds
#
#  176: 546.566040, 399.036102 avg loss, 0.000001 rate, 1.556723 seconds, 11264 images
# Loaded: 0.000036 seconds
#
#  177: 544.706970, 413.603180 avg loss, 0.000001 rate, 1.578137 seconds, 11328 images
# Loaded: 0.000033 seconds
#
#  178: 542.441956, 426.487061 avg loss, 0.000001 rate, 1.541533 seconds, 11392 images
# Loaded: 0.000033 seconds
#
#  179: 540.459839, 437.884338 avg loss, 0.000001 rate, 1.534465 seconds, 11456 images
# Loaded: 0.000041 seconds
#
#  180: 537.784363, 447.874329 avg loss, 0.000001 rate, 1.566649 seconds, 11520 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.588718 seconds
#
#  181: 280.586060, 431.145508 avg loss, 0.000001 rate, 0.832780 seconds, 11584 images
# Loaded: 0.000044 seconds
#
#  182: 279.508575, 415.981812 avg loss, 0.000001 rate, 0.862746 seconds, 11648 images
# Loaded: 0.000046 seconds
#
#  183: 278.385010, 402.222137 avg loss, 0.000001 rate, 0.840508 seconds, 11712 images
# Loaded: 0.000033 seconds
#
#  184: 276.840302, 389.683960 avg loss, 0.000001 rate, 0.836139 seconds, 11776 images
# Loaded: 0.000034 seconds
#
#  185: 275.762482, 378.291809 avg loss, 0.000001 rate, 0.837363 seconds, 11840 images
# Loaded: 0.000034 seconds
#
#  186: 274.726257, 367.935242 avg loss, 0.000001 rate, 0.851741 seconds, 11904 images
# Loaded: 0.000036 seconds
#
#  187: 273.551208, 358.496826 avg loss, 0.000001 rate, 0.846051 seconds, 11968 images
# Loaded: 0.000036 seconds
#
#  188: 272.059631, 349.853119 avg loss, 0.000001 rate, 0.851215 seconds, 12032 images
# Loaded: 0.000035 seconds
#
#  189: 270.754242, 341.943237 avg loss, 0.000001 rate, 0.837989 seconds, 12096 images
# Loaded: 0.000028 seconds
#
#  190: 269.561401, 334.705048 avg loss, 0.000001 rate, 0.857443 seconds, 12160 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.510072 seconds
#
#  191: 193.284302, 320.562988 avg loss, 0.000001 rate, 0.686114 seconds, 12224 images
# Loaded: 0.001827 seconds
#
#  192: 192.428726, 307.749573 avg loss, 0.000001 rate, 0.677695 seconds, 12288 images
# Loaded: 0.002075 seconds
#
#  193: 191.525772, 296.127197 avg loss, 0.000001 rate, 0.682923 seconds, 12352 images
# Loaded: 0.000035 seconds
#
#  194: 190.806564, 285.595123 avg loss, 0.000001 rate, 0.681808 seconds, 12416 images
# Loaded: 0.003348 seconds
#
#  195: 189.913422, 276.026947 avg loss, 0.000001 rate, 0.698824 seconds, 12480 images
# Loaded: 0.000033 seconds
#
#  196: 189.416550, 267.365906 avg loss, 0.000001 rate, 0.726929 seconds, 12544 images
# Loaded: 0.000033 seconds
#
#  197: 188.518326, 259.481140 avg loss, 0.000002 rate, 0.675541 seconds, 12608 images
# Loaded: 0.011686 seconds
#
#  198: 187.521072, 252.285126 avg loss, 0.000002 rate, 0.682475 seconds, 12672 images
# Loaded: 0.000034 seconds
#
#  199: 187.134155, 245.770035 avg loss, 0.000002 rate, 0.683932 seconds, 12736 images
# Loaded: 0.018827 seconds
#
#  200: 186.327316, 239.825760 avg loss, 0.000002 rate, 0.673427 seconds, 12800 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.620422 seconds
#
#  201: 219.960693, 237.839249 avg loss, 0.000002 rate, 0.782712 seconds, 12864 images
# Loaded: 0.068836 seconds
#
#  202: 219.155884, 235.970917 avg loss, 0.000002 rate, 0.762892 seconds, 12928 images
# Loaded: 0.063923 seconds
#
#  203: 218.743713, 234.248199 avg loss, 0.000002 rate, 0.843900 seconds, 12992 images
# Loaded: 0.000707 seconds
#
#  204: 217.440430, 232.567429 avg loss, 0.000002 rate, 0.822160 seconds, 13056 images
# Loaded: 0.031845 seconds
#
#  205: 216.873154, 230.998001 avg loss, 0.000002 rate, 0.835898 seconds, 13120 images
# Loaded: 0.042320 seconds
#
#  206: 215.781372, 229.476334 avg loss, 0.000002 rate, 0.838839 seconds, 13184 images
# Loaded: 0.069174 seconds
#
#  207: 214.775116, 228.006210 avg loss, 0.000002 rate, 0.859543 seconds, 13248 images
# Loaded: 0.007725 seconds
#
#  208: 213.797455, 226.585327 avg loss, 0.000002 rate, 0.757642 seconds, 13312 images
# Loaded: 0.056874 seconds
#
#  209: 212.905975, 225.217392 avg loss, 0.000002 rate, 0.755521 seconds, 13376 images
# Loaded: 0.107623 seconds
#
#  210: 211.875916, 223.883240 avg loss, 0.000002 rate, 0.791562 seconds, 13440 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.684458 seconds
#
#  211: 372.192902, 238.714203 avg loss, 0.000002 rate, 1.230527 seconds, 13504 images
# Loaded: 0.000038 seconds
#
#  212: 370.400421, 251.882828 avg loss, 0.000002 rate, 1.246178 seconds, 13568 images
# Loaded: 0.000035 seconds
#
#  213: 368.305176, 263.525055 avg loss, 0.000002 rate, 1.228980 seconds, 13632 images
# Loaded: 0.000038 seconds
#
#  214: 365.960358, 273.768585 avg loss, 0.000002 rate, 1.231798 seconds, 13696 images
# Loaded: 0.000032 seconds
#
#  215: 364.030945, 282.794830 avg loss, 0.000002 rate, 1.232473 seconds, 13760 images
# Loaded: 0.000036 seconds
#
#  216: 361.688446, 290.684204 avg loss, 0.000002 rate, 1.235195 seconds, 13824 images
# Loaded: 0.000051 seconds
#
#  217: 358.894501, 297.505249 avg loss, 0.000002 rate, 1.245605 seconds, 13888 images
# Loaded: 0.000034 seconds
#
#  218: 356.499176, 303.404633 avg loss, 0.000002 rate, 1.237456 seconds, 13952 images
# Loaded: 0.000036 seconds
#
#  219: 353.679382, 308.432098 avg loss, 0.000002 rate, 1.215707 seconds, 14016 images
# Loaded: 0.000034 seconds
#
#  220: 350.804535, 312.669342 avg loss, 0.000002 rate, 1.268025 seconds, 14080 images
# Resizing
# 576 x 576
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.619037 seconds
#
#  221: 439.645447, 325.366943 avg loss, 0.000002 rate, 1.554132 seconds, 14144 images
# Loaded: 0.000043 seconds
#
#  222: 435.750397, 336.405273 avg loss, 0.000002 rate, 1.544296 seconds, 14208 images
# Loaded: 0.000040 seconds
#
#  223: 431.761902, 345.940948 avg loss, 0.000002 rate, 1.564076 seconds, 14272 images
# Loaded: 0.000035 seconds
#
#  224: 427.544342, 354.101288 avg loss, 0.000003 rate, 1.551976 seconds, 14336 images
# Loaded: 0.000035 seconds
#
#  225: 423.159302, 361.007080 avg loss, 0.000003 rate, 1.566213 seconds, 14400 images
# Loaded: 0.000040 seconds
#
#  226: 418.527649, 366.759125 avg loss, 0.000003 rate, 1.545474 seconds, 14464 images
# Loaded: 0.000037 seconds
#
#  227: 413.948914, 371.478119 avg loss, 0.000003 rate, 1.539999 seconds, 14528 images
# Loaded: 0.000034 seconds
#
#  228: 409.181305, 375.248444 avg loss, 0.000003 rate, 1.566758 seconds, 14592 images
# Loaded: 0.000029 seconds
#
#  229: 404.377838, 378.161377 avg loss, 0.000003 rate, 1.557306 seconds, 14656 images
# Loaded: 0.000031 seconds
#
#  230: 399.432251, 380.288452 avg loss, 0.000003 rate, 1.581920 seconds, 14720 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.531075 seconds
#
#  231: 177.559448, 360.015564 avg loss, 0.000003 rate, 0.742113 seconds, 14784 images
# Loaded: 0.000032 seconds
#
#  232: 174.761459, 341.490143 avg loss, 0.000003 rate, 0.766452 seconds, 14848 images
# Loaded: 0.000032 seconds
#
#  233: 172.839844, 324.625122 avg loss, 0.000003 rate, 0.748892 seconds, 14912 images
# Loaded: 0.000033 seconds
#
#  234: 170.953400, 309.257935 avg loss, 0.000003 rate, 0.765053 seconds, 14976 images
# Loaded: 0.000032 seconds
#
#  235: 169.082718, 295.240417 avg loss, 0.000003 rate, 0.758516 seconds, 15040 images
# Loaded: 0.000026 seconds
#
#  236: 167.191666, 282.435547 avg loss, 0.000003 rate, 0.763601 seconds, 15104 images
# Loaded: 0.000034 seconds
#
#  237: 165.270157, 270.718994 avg loss, 0.000003 rate, 0.752956 seconds, 15168 images
# Loaded: 0.000033 seconds
#
#  238: 163.677567, 260.014862 avg loss, 0.000003 rate, 0.785239 seconds, 15232 images
# Loaded: 0.000048 seconds
#
#  239: 162.354111, 250.248779 avg loss, 0.000003 rate, 0.758615 seconds, 15296 images
# Loaded: 0.000045 seconds
#
#  240: 160.638885, 241.287796 avg loss, 0.000003 rate, 0.790189 seconds, 15360 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.647416 seconds
#
#  241: 315.566315, 248.715652 avg loss, 0.000003 rate, 1.406251 seconds, 15424 images
# Loaded: 0.000034 seconds
#
#  242: 312.154846, 255.059570 avg loss, 0.000003 rate, 1.459787 seconds, 15488 images
# Loaded: 0.000054 seconds
#
#  243: 308.893616, 260.442963 avg loss, 0.000003 rate, 1.457667 seconds, 15552 images
# Loaded: 0.000039 seconds
#
#  244: 305.341431, 264.932800 avg loss, 0.000004 rate, 1.437510 seconds, 15616 images
# Loaded: 0.000031 seconds
#
#  245: 301.658142, 268.605347 avg loss, 0.000004 rate, 1.460861 seconds, 15680 images
# Loaded: 0.000037 seconds
#
#  246: 297.705444, 271.515350 avg loss, 0.000004 rate, 1.453998 seconds, 15744 images
# Loaded: 0.000031 seconds
#
#  247: 293.648834, 273.728699 avg loss, 0.000004 rate, 1.399543 seconds, 15808 images
# Loaded: 0.000046 seconds
#
#  248: 289.854614, 275.341278 avg loss, 0.000004 rate, 1.399607 seconds, 15872 images
# Loaded: 0.000040 seconds
#
#  249: 285.932373, 276.400391 avg loss, 0.000004 rate, 1.455496 seconds, 15936 images
# Loaded: 0.000032 seconds
#
#  250: 282.049988, 276.965363 avg loss, 0.000004 rate, 1.445867 seconds, 16000 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.597180 seconds
#
#  251: 164.020477, 265.670868 avg loss, 0.000004 rate, 0.824466 seconds, 16064 images
# Loaded: 0.000028 seconds
#
#  252: 161.558350, 255.259613 avg loss, 0.000004 rate, 0.839960 seconds, 16128 images
# Loaded: 0.000036 seconds
#
#  253: 159.669586, 245.700607 avg loss, 0.000004 rate, 0.863978 seconds, 16192 images
# Loaded: 0.000035 seconds
#
#  254: 157.340897, 236.864639 avg loss, 0.000004 rate, 0.838504 seconds, 16256 images
# Loaded: 0.000033 seconds
#
#  255: 155.178513, 228.696030 avg loss, 0.000004 rate, 0.845720 seconds, 16320 images
# Loaded: 0.000033 seconds
#
#  256: 152.929031, 221.119324 avg loss, 0.000004 rate, 0.836915 seconds, 16384 images
# Loaded: 0.000034 seconds
#
#  257: 151.182205, 214.125610 avg loss, 0.000004 rate, 0.840002 seconds, 16448 images
# Loaded: 0.000029 seconds
#
#  258: 149.423584, 207.655411 avg loss, 0.000004 rate, 0.841057 seconds, 16512 images
# Loaded: 0.000037 seconds
#
#  259: 147.114517, 201.601318 avg loss, 0.000004 rate, 0.831727 seconds, 16576 images
# Loaded: 0.000036 seconds
#
#  260: 145.134003, 195.954590 avg loss, 0.000005 rate, 0.864257 seconds, 16640 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.547022 seconds
#
#  261: 165.972000, 192.956329 avg loss, 0.000005 rate, 1.055030 seconds, 16704 images
# Loaded: 0.000031 seconds
#
#  262: 164.328949, 190.093597 avg loss, 0.000005 rate, 1.049831 seconds, 16768 images
# Loaded: 0.000034 seconds
#
#  263: 162.001236, 187.284363 avg loss, 0.000005 rate, 1.052626 seconds, 16832 images
# Loaded: 0.000032 seconds
#
#  264: 160.168991, 184.572830 avg loss, 0.000005 rate, 1.033532 seconds, 16896 images
# Loaded: 0.000032 seconds
#
#  265: 157.498703, 181.865417 avg loss, 0.000005 rate, 1.065797 seconds, 16960 images
# Loaded: 0.000034 seconds
#
#  266: 155.572159, 179.236084 avg loss, 0.000005 rate, 1.054047 seconds, 17024 images
# Loaded: 0.000034 seconds
#
#  267: 153.686462, 176.681122 avg loss, 0.000005 rate, 1.042393 seconds, 17088 images
# Loaded: 0.000039 seconds
#
#  268: 151.685883, 174.181595 avg loss, 0.000005 rate, 1.092867 seconds, 17152 images
# Loaded: 0.000037 seconds
#
#  269: 149.459122, 171.709351 avg loss, 0.000005 rate, 1.135948 seconds, 17216 images
# Loaded: 0.000044 seconds
#
#  270: 147.679214, 169.306335 avg loss, 0.000005 rate, 1.160079 seconds, 17280 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.567363 seconds
#
#  271: 91.558441, 161.531540 avg loss, 0.000005 rate, 0.734919 seconds, 17344 images
# Loaded: 0.084197 seconds
#
#  272: 90.182968, 154.396683 avg loss, 0.000005 rate, 0.662675 seconds, 17408 images
# Loaded: 0.164243 seconds
#
#  273: 88.885696, 147.845581 avg loss, 0.000006 rate, 0.750769 seconds, 17472 images
# Loaded: 0.068183 seconds
#
#  274: 88.093346, 141.870361 avg loss, 0.000006 rate, 0.746466 seconds, 17536 images
# Loaded: 0.047071 seconds
#
#  275: 87.126244, 136.395950 avg loss, 0.000006 rate, 0.707374 seconds, 17600 images
# Loaded: 0.109301 seconds
#
#  276: 85.656601, 131.322021 avg loss, 0.000006 rate, 0.737902 seconds, 17664 images
# Loaded: 0.070787 seconds
#
#  277: 84.748665, 126.664688 avg loss, 0.000006 rate, 0.712986 seconds, 17728 images
# Loaded: 0.076256 seconds
#
#  278: 84.000687, 122.398285 avg loss, 0.000006 rate, 0.760936 seconds, 17792 images
# Loaded: 0.034673 seconds
#
#  279: 82.945824, 118.453041 avg loss, 0.000006 rate, 0.662552 seconds, 17856 images
# Loaded: 0.020661 seconds
#
#  280: 82.010162, 114.808754 avg loss, 0.000006 rate, 0.681750 seconds, 17920 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.470408 seconds
#
#  281: 112.045151, 114.532394 avg loss, 0.000006 rate, 0.827361 seconds, 17984 images
# Loaded: 0.000033 seconds
#
#  282: 110.722687, 114.151421 avg loss, 0.000006 rate, 0.848298 seconds, 18048 images
# Loaded: 0.000039 seconds
#
#  283: 109.818047, 113.718086 avg loss, 0.000006 rate, 0.835092 seconds, 18112 images
# Loaded: 0.000049 seconds
#
#  284: 107.898117, 113.136093 avg loss, 0.000007 rate, 0.845548 seconds, 18176 images
# Loaded: 0.000035 seconds
#
#  285: 107.186615, 112.541145 avg loss, 0.000007 rate, 0.856839 seconds, 18240 images
# Loaded: 0.000040 seconds
#
#  286: 105.747650, 111.861794 avg loss, 0.000007 rate, 0.852422 seconds, 18304 images
# Loaded: 0.000034 seconds
#
#  287: 104.614021, 111.137016 avg loss, 0.000007 rate, 0.842066 seconds, 18368 images
# Loaded: 0.000033 seconds
#
#  288: 102.894318, 110.312744 avg loss, 0.000007 rate, 0.837207 seconds, 18432 images
# Loaded: 0.000033 seconds
#
#  289: 101.925011, 109.473969 avg loss, 0.000007 rate, 0.844757 seconds, 18496 images
# Loaded: 0.000032 seconds
#
#  290: 100.282127, 108.554787 avg loss, 0.000007 rate, 0.831090 seconds, 18560 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.585825 seconds
#
#  291: 99.137482, 107.613060 avg loss, 0.000007 rate, 0.828263 seconds, 18624 images
# Loaded: 0.000044 seconds
#
#  292: 98.094933, 106.661247 avg loss, 0.000007 rate, 0.841513 seconds, 18688 images
# Loaded: 0.000037 seconds
#
#  293: 96.609528, 105.656075 avg loss, 0.000007 rate, 0.867361 seconds, 18752 images
# Loaded: 0.000032 seconds
#
#  294: 95.595444, 104.650009 avg loss, 0.000007 rate, 0.834058 seconds, 18816 images
# Loaded: 0.000035 seconds
#
#  295: 94.331490, 103.618156 avg loss, 0.000008 rate, 0.830462 seconds, 18880 images
# Loaded: 0.000052 seconds
#
#  296: 92.996544, 102.555992 avg loss, 0.000008 rate, 0.836976 seconds, 18944 images
# Loaded: 0.000036 seconds
#
#  297: 91.597839, 101.460175 avg loss, 0.000008 rate, 0.860507 seconds, 19008 images
# Loaded: 0.000032 seconds
#
#  298: 90.758301, 100.389984 avg loss, 0.000008 rate, 0.831765 seconds, 19072 images
# Loaded: 0.000036 seconds
#
#  299: 89.328598, 99.283844 avg loss, 0.000008 rate, 0.840599 seconds, 19136 images
# Loaded: 0.000038 seconds
#
#  300: 87.763626, 98.131821 avg loss, 0.000008 rate, 0.879785 seconds, 19200 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.579209 seconds
#
#  301: 62.999279, 94.618568 avg loss, 0.000008 rate, 0.673486 seconds, 19264 images
# Loaded: 0.020808 seconds
#
#  302: 62.120853, 91.368797 avg loss, 0.000008 rate, 0.694300 seconds, 19328 images
# Loaded: 0.000032 seconds
#
#  303: 61.539661, 88.385887 avg loss, 0.000008 rate, 0.709636 seconds, 19392 images
# Loaded: 0.000031 seconds
#
#  304: 60.841908, 85.631493 avg loss, 0.000009 rate, 0.698302 seconds, 19456 images
# Loaded: 0.011650 seconds
#
#  305: 59.907242, 83.059067 avg loss, 0.000009 rate, 0.666891 seconds, 19520 images
# Loaded: 0.000040 seconds
#
#  306: 59.296528, 80.682816 avg loss, 0.000009 rate, 0.740491 seconds, 19584 images
# Loaded: 0.000034 seconds
#
#  307: 58.645134, 78.479050 avg loss, 0.000009 rate, 0.698563 seconds, 19648 images
# Loaded: 0.011029 seconds
#
#  308: 57.979164, 76.429062 avg loss, 0.000009 rate, 0.672866 seconds, 19712 images
# Loaded: 0.000034 seconds
#
#  309: 57.131191, 74.499275 avg loss, 0.000009 rate, 0.685211 seconds, 19776 images
# Loaded: 0.005545 seconds
#
#  310: 56.537876, 72.703133 avg loss, 0.000009 rate, 0.664414 seconds, 19840 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.524608 seconds
#
#  311: 55.636440, 70.996460 avg loss, 0.000009 rate, 0.691913 seconds, 19904 images
# Loaded: 0.000049 seconds
#
#  312: 55.087357, 69.405548 avg loss, 0.000009 rate, 0.687140 seconds, 19968 images
# Loaded: 0.000044 seconds
#
#  313: 54.420429, 67.907036 avg loss, 0.000010 rate, 0.768686 seconds, 20032 images
# Loaded: 0.000031 seconds
#
#  314: 54.036530, 66.519989 avg loss, 0.000010 rate, 0.664643 seconds, 20096 images
# Loaded: 0.020662 seconds
#
#  315: 52.984840, 65.166473 avg loss, 0.000010 rate, 0.683504 seconds, 20160 images
# Loaded: 0.000033 seconds
#
#  316: 52.584694, 63.908295 avg loss, 0.000010 rate, 0.686211 seconds, 20224 images
# Loaded: 0.000031 seconds
#
#  317: 52.196075, 62.737072 avg loss, 0.000010 rate, 0.701581 seconds, 20288 images
# Loaded: 0.000034 seconds
#
#  318: 51.269245, 61.590290 avg loss, 0.000010 rate, 0.689963 seconds, 20352 images
# Loaded: 0.000033 seconds
#
#  319: 50.914242, 60.522686 avg loss, 0.000010 rate, 0.703140 seconds, 20416 images
# Loaded: 0.000034 seconds
#
#  320: 49.970238, 59.467442 avg loss, 0.000010 rate, 0.696023 seconds, 20480 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.538029 seconds
#
#  321: 58.480595, 59.368755 avg loss, 0.000011 rate, 0.744221 seconds, 20544 images
# Loaded: 0.000034 seconds
#
#  322: 57.318233, 59.163704 avg loss, 0.000011 rate, 0.777562 seconds, 20608 images
# Loaded: 0.000034 seconds
#
#  323: 57.028027, 58.950134 avg loss, 0.000011 rate, 0.766611 seconds, 20672 images
# Loaded: 0.000041 seconds
#
#  324: 56.352978, 58.690418 avg loss, 0.000011 rate, 0.792021 seconds, 20736 images
# Loaded: 0.000032 seconds
#
#  325: 55.602058, 58.381584 avg loss, 0.000011 rate, 0.736754 seconds, 20800 images
# Loaded: 0.000059 seconds
#
#  326: 54.556515, 57.999077 avg loss, 0.000011 rate, 0.752517 seconds, 20864 images
# Loaded: 0.000031 seconds
#
#  327: 53.978695, 57.597038 avg loss, 0.000011 rate, 0.764713 seconds, 20928 images
# Loaded: 0.000031 seconds
#
#  328: 53.154137, 57.152748 avg loss, 0.000012 rate, 0.753634 seconds, 20992 images
# Loaded: 0.000033 seconds
#
#  329: 52.665653, 56.704041 avg loss, 0.000012 rate, 0.745179 seconds, 21056 images
# Loaded: 0.000033 seconds
#
#  330: 51.803429, 56.213978 avg loss, 0.000012 rate, 0.756760 seconds, 21120 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.525486 seconds
#
#  331: 77.655602, 58.358139 avg loss, 0.000012 rate, 1.153302 seconds, 21184 images
# Loaded: 0.000038 seconds
#
#  332: 76.793694, 60.201694 avg loss, 0.000012 rate, 1.139847 seconds, 21248 images
# Loaded: 0.000037 seconds
#
#  333: 75.592987, 61.740826 avg loss, 0.000012 rate, 1.122202 seconds, 21312 images
# Loaded: 0.000051 seconds
#
#  334: 74.226540, 62.989395 avg loss, 0.000012 rate, 1.132141 seconds, 21376 images
# Loaded: 0.000037 seconds
#
#  335: 73.042679, 63.994724 avg loss, 0.000013 rate, 1.158230 seconds, 21440 images
# Loaded: 0.000036 seconds
#
#  336: 71.562958, 64.751549 avg loss, 0.000013 rate, 1.159145 seconds, 21504 images
# Loaded: 0.000029 seconds
#
#  337: 70.274162, 65.303810 avg loss, 0.000013 rate, 1.121455 seconds, 21568 images
# Loaded: 0.000034 seconds
#
#  338: 68.804001, 65.653831 avg loss, 0.000013 rate, 1.127966 seconds, 21632 images
# Loaded: 0.000038 seconds
#
#  339: 67.644966, 65.852943 avg loss, 0.000013 rate, 1.128606 seconds, 21696 images
# Loaded: 0.000031 seconds
#
#  340: 66.456764, 65.913322 avg loss, 0.000013 rate, 1.146520 seconds, 21760 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.512971 seconds
#
#  341: 73.480270, 66.670013 avg loss, 0.000014 rate, 1.209319 seconds, 21824 images
# Loaded: 0.000037 seconds
#
#  342: 71.859947, 67.189011 avg loss, 0.000014 rate, 1.232610 seconds, 21888 images
# Loaded: 0.000047 seconds
#
#  343: 70.341988, 67.504311 avg loss, 0.000014 rate, 1.220126 seconds, 21952 images
# Loaded: 0.000036 seconds
#
#  344: 68.703621, 67.624245 avg loss, 0.000014 rate, 1.215066 seconds, 22016 images
# Loaded: 0.000037 seconds
#
#  345: 67.272316, 67.589050 avg loss, 0.000014 rate, 1.213755 seconds, 22080 images
# Loaded: 0.000051 seconds
#
#  346: 65.500626, 67.380211 avg loss, 0.000014 rate, 1.258120 seconds, 22144 images
# Loaded: 0.000037 seconds
#
#  347: 64.040718, 67.046265 avg loss, 0.000014 rate, 1.230021 seconds, 22208 images
# Loaded: 0.000033 seconds
#
#  348: 62.570419, 66.598679 avg loss, 0.000015 rate, 1.228121 seconds, 22272 images
# Loaded: 0.000038 seconds
#
#  349: 60.867714, 66.025581 avg loss, 0.000015 rate, 1.245114 seconds, 22336 images
# Loaded: 0.000036 seconds
#
#  350: 59.592808, 65.382301 avg loss, 0.000015 rate, 1.246386 seconds, 22400 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.577091 seconds
#
#  351: 34.017197, 62.245792 avg loss, 0.000015 rate, 0.735699 seconds, 22464 images
# Loaded: 0.000135 seconds
#
#  352: 33.655247, 59.386738 avg loss, 0.000015 rate, 0.799883 seconds, 22528 images
# Loaded: 0.029643 seconds
#
#  353: 32.598095, 56.707874 avg loss, 0.000016 rate, 0.860742 seconds, 22592 images
# Loaded: 0.000033 seconds
#
#  354: 32.320354, 54.269123 avg loss, 0.000016 rate, 0.826180 seconds, 22656 images
# Loaded: 0.024720 seconds
#
#  355: 31.483578, 51.990570 avg loss, 0.000016 rate, 0.756096 seconds, 22720 images
# Loaded: 0.088722 seconds
#
#  356: 30.529608, 49.844475 avg loss, 0.000016 rate, 0.802430 seconds, 22784 images
# Loaded: 0.045004 seconds
#
#  357: 30.355953, 47.895622 avg loss, 0.000016 rate, 0.798134 seconds, 22848 images
# Loaded: 0.048812 seconds
#
#  358: 30.121601, 46.118221 avg loss, 0.000016 rate, 0.845227 seconds, 22912 images
# Loaded: 0.022278 seconds
#
#  359: 29.379875, 44.444386 avg loss, 0.000017 rate, 0.815386 seconds, 22976 images
# Loaded: 0.049088 seconds
#
#  360: 28.483686, 42.848316 avg loss, 0.000017 rate, 0.814657 seconds, 23040 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.813138 seconds
#
#  361: 46.936264, 43.257111 avg loss, 0.000017 rate, 1.326975 seconds, 23104 images
# Loaded: 0.000046 seconds
#
#  362: 45.979710, 43.529369 avg loss, 0.000017 rate, 1.220961 seconds, 23168 images
# Loaded: 0.000036 seconds
#
#  363: 45.120659, 43.688499 avg loss, 0.000017 rate, 1.234111 seconds, 23232 images
# Loaded: 0.000036 seconds
#
#  364: 43.863197, 43.705971 avg loss, 0.000018 rate, 1.240848 seconds, 23296 images
# Loaded: 0.000052 seconds
#
#  365: 43.044109, 43.639786 avg loss, 0.000018 rate, 1.225316 seconds, 23360 images
# Loaded: 0.000031 seconds
#
#  366: 42.289913, 43.504799 avg loss, 0.000018 rate, 1.222509 seconds, 23424 images
# Loaded: 0.000033 seconds
#
#  367: 41.205296, 43.274849 avg loss, 0.000018 rate, 1.218663 seconds, 23488 images
# Loaded: 0.000037 seconds
#
#  368: 40.115078, 42.958870 avg loss, 0.000018 rate, 1.237799 seconds, 23552 images
# Loaded: 0.000036 seconds
#
#  369: 39.497158, 42.612698 avg loss, 0.000019 rate, 1.248290 seconds, 23616 images
# Loaded: 0.000035 seconds
#
#  370: 38.612972, 42.212727 avg loss, 0.000019 rate, 1.221205 seconds, 23680 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.517960 seconds
#
#  371: 19.779623, 39.969418 avg loss, 0.000019 rate, 0.680588 seconds, 23744 images
# Loaded: 0.009616 seconds
#
#  372: 19.511377, 37.923615 avg loss, 0.000019 rate, 0.654797 seconds, 23808 images
# Loaded: 0.023177 seconds
#
#  373: 19.487240, 36.079979 avg loss, 0.000019 rate, 0.667282 seconds, 23872 images
# Loaded: 0.021472 seconds
#
#  374: 19.081743, 34.380154 avg loss, 0.000020 rate, 0.665869 seconds, 23936 images
# Loaded: 0.019991 seconds
#
#  375: 18.608725, 32.803009 avg loss, 0.000020 rate, 0.662132 seconds, 24000 images
# Loaded: 0.017965 seconds
#
#  376: 18.301138, 31.352821 avg loss, 0.000020 rate, 0.653085 seconds, 24064 images
# Loaded: 0.016727 seconds
#
#  377: 18.127584, 30.030298 avg loss, 0.000020 rate, 0.671152 seconds, 24128 images
# Loaded: 0.028125 seconds
#
#  378: 17.793785, 28.806646 avg loss, 0.000020 rate, 0.680827 seconds, 24192 images
# Loaded: 0.000025 seconds
#
#  379: 17.383890, 27.664371 avg loss, 0.000021 rate, 0.650077 seconds, 24256 images
# Loaded: 0.025481 seconds
#
#  380: 17.277037, 26.625639 avg loss, 0.000021 rate, 0.673665 seconds, 24320 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.748999 seconds
#
#  381: 43.289486, 28.292025 avg loss, 0.000021 rate, 1.680270 seconds, 24384 images
# Loaded: 0.000038 seconds
#
#  382: 41.848331, 29.647655 avg loss, 0.000021 rate, 1.667814 seconds, 24448 images
# Loaded: 0.000042 seconds
#
#  383: 41.010963, 30.783987 avg loss, 0.000022 rate, 1.640373 seconds, 24512 images
# Loaded: 0.000032 seconds
#
# ...
# Loaded: 0.000035 seconds
#
#  8466: 0.285712, 0.314836 avg loss, 0.001000 rate, 1.157993 seconds, 541824 images
# Loaded: 0.000041 seconds
#
#  8467: 0.334640, 0.316817 avg loss, 0.001000 rate, 1.179419 seconds, 541888 images
# Loaded: 0.000046 seconds
#
#  8468: 0.364169, 0.321552 avg loss, 0.001000 rate, 1.139930 seconds, 541952 images
# Loaded: 0.000031 seconds
#
#  8469: 0.353697, 0.324766 avg loss, 0.001000 rate, 1.176562 seconds, 542016 images
# Loaded: 0.000031 seconds
#
#  8470: 0.262523, 0.318542 avg loss, 0.001000 rate, 1.163600 seconds, 542080 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.569819 seconds
#
#  8471: 0.272935, 0.313981 avg loss, 0.001000 rate, 0.754001 seconds, 542144 images
# Loaded: 0.000031 seconds
#
#  8472: 0.246425, 0.307226 avg loss, 0.001000 rate, 0.773216 seconds, 542208 images
# Loaded: 0.000052 seconds
#
#  8473: 0.169187, 0.293422 avg loss, 0.001000 rate, 0.771704 seconds, 542272 images
# Loaded: 0.000046 seconds
#
#  8474: 0.270453, 0.291125 avg loss, 0.001000 rate, 0.770517 seconds, 542336 images
# Loaded: 0.000033 seconds
#
#  8475: 0.281204, 0.290133 avg loss, 0.001000 rate, 0.746257 seconds, 542400 images
# Loaded: 0.000034 seconds
#
#  8476: 0.315262, 0.292646 avg loss, 0.001000 rate, 0.754052 seconds, 542464 images
# Loaded: 0.000035 seconds
#
#  8477: 0.252015, 0.288583 avg loss, 0.001000 rate, 0.784889 seconds, 542528 images
# Loaded: 0.000032 seconds
#
#  8478: 0.235297, 0.283254 avg loss, 0.001000 rate, 0.787812 seconds, 542592 images
# Loaded: 0.000039 seconds
#
#  8479: 0.219125, 0.276841 avg loss, 0.001000 rate, 0.795293 seconds, 542656 images
# Loaded: 0.069242 seconds
#
#  8480: 0.157360, 0.264893 avg loss, 0.001000 rate, 0.812829 seconds, 542720 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.765683 seconds
#
#  8481: 0.418373, 0.280241 avg loss, 0.001000 rate, 1.286486 seconds, 542784 images
# Loaded: 0.000038 seconds
#
#  8482: 0.336687, 0.285886 avg loss, 0.001000 rate, 1.277919 seconds, 542848 images
# Loaded: 0.000031 seconds
#
#  8483: 0.256643, 0.282961 avg loss, 0.001000 rate, 1.204601 seconds, 542912 images
# Loaded: 0.000035 seconds
#
#  8484: 0.251891, 0.279854 avg loss, 0.001000 rate, 1.231584 seconds, 542976 images
# Loaded: 0.000040 seconds
#
#  8485: 0.273984, 0.279267 avg loss, 0.001000 rate, 1.246866 seconds, 543040 images
# Loaded: 0.000040 seconds
#
#  8486: 0.246879, 0.276028 avg loss, 0.001000 rate, 1.238174 seconds, 543104 images
# Loaded: 0.000038 seconds
#
#  8487: 0.275586, 0.275984 avg loss, 0.001000 rate, 1.255006 seconds, 543168 images
# Loaded: 0.000035 seconds
#
#  8488: 0.255593, 0.273945 avg loss, 0.001000 rate, 1.237119 seconds, 543232 images
# Loaded: 0.000035 seconds
#
#  8489: 0.195158, 0.266066 avg loss, 0.001000 rate, 1.244550 seconds, 543296 images
# Loaded: 0.000037 seconds
#
#  8490: 0.156673, 0.255127 avg loss, 0.001000 rate, 1.236028 seconds, 543360 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.570436 seconds
#
#  8491: 0.382910, 0.267905 avg loss, 0.001000 rate, 0.740959 seconds, 543424 images
# Loaded: 0.000033 seconds
#
#  8492: 0.275106, 0.268625 avg loss, 0.001000 rate, 0.793763 seconds, 543488 images
# Loaded: 0.000036 seconds
#
#  8493: 0.177826, 0.259545 avg loss, 0.001000 rate, 0.771728 seconds, 543552 images
# Loaded: 0.000031 seconds
#
#  8494: 0.186229, 0.252214 avg loss, 0.001000 rate, 0.788166 seconds, 543616 images
# Loaded: 0.000051 seconds
#
#  8495: 0.173921, 0.244385 avg loss, 0.001000 rate, 0.799178 seconds, 543680 images
# Loaded: 0.000029 seconds
#
#  8496: 0.251965, 0.245143 avg loss, 0.001000 rate, 0.764099 seconds, 543744 images
# Loaded: 0.000034 seconds
#
#  8497: 0.284930, 0.249121 avg loss, 0.001000 rate, 0.800871 seconds, 543808 images
# Loaded: 0.000040 seconds
#
#  8498: 0.260122, 0.250221 avg loss, 0.001000 rate, 0.769047 seconds, 543872 images
# Loaded: 0.000034 seconds
#
#  8499: 0.222106, 0.247410 avg loss, 0.001000 rate, 0.768254 seconds, 543936 images
# Loaded: 0.000032 seconds
#
#  8500: 0.165235, 0.239192 avg loss, 0.001000 rate, 0.748501 seconds, 544000 images
# Saving weights to /content/gdrive/My Drive/darknet/backup/yolov3-tiny_last.weights
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.593400 seconds
#
#  8501: 0.608486, 0.276122 avg loss, 0.001000 rate, 1.441737 seconds, 544064 images
# Loaded: 0.000040 seconds
#
#  8502: 0.303019, 0.278811 avg loss, 0.001000 rate, 1.459833 seconds, 544128 images
# Loaded: 0.000039 seconds
#
#  8503: 0.295846, 0.280515 avg loss, 0.001000 rate, 1.465800 seconds, 544192 images
# Loaded: 0.000036 seconds
#
#  8504: 0.173542, 0.269818 avg loss, 0.001000 rate, 1.426553 seconds, 544256 images
# Loaded: 0.000039 seconds
#
#  8505: 0.220234, 0.264859 avg loss, 0.001000 rate, 1.441108 seconds, 544320 images
# Loaded: 0.000044 seconds
#
#  8506: 0.360248, 0.274398 avg loss, 0.001000 rate, 1.460464 seconds, 544384 images
# Loaded: 0.000034 seconds
#
#  8507: 0.413430, 0.288301 avg loss, 0.001000 rate, 1.487582 seconds, 544448 images
# Loaded: 0.000042 seconds
#
#  8508: 0.269769, 0.286448 avg loss, 0.001000 rate, 1.468357 seconds, 544512 images
# Loaded: 0.000036 seconds
#
#  8509: 0.264960, 0.284299 avg loss, 0.001000 rate, 1.464321 seconds, 544576 images
# Loaded: 0.000041 seconds
#
#  8510: 0.212377, 0.277107 avg loss, 0.001000 rate, 1.515771 seconds, 544640 images
# Resizing
# 544 x 544
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.922657 seconds
#
#  8511: 0.212860, 0.270682 avg loss, 0.001000 rate, 1.472477 seconds, 544704 images
# Loaded: 0.000040 seconds
#
#  8512: 0.269546, 0.270569 avg loss, 0.001000 rate, 1.547567 seconds, 544768 images
# Loaded: 0.000034 seconds
#
#  8513: 0.300106, 0.273522 avg loss, 0.001000 rate, 1.477931 seconds, 544832 images
# Loaded: 0.000040 seconds
#
#  8514: 0.266287, 0.272799 avg loss, 0.001000 rate, 1.481064 seconds, 544896 images
# Loaded: 0.000040 seconds
#
#  8515: 0.248834, 0.270402 avg loss, 0.001000 rate, 1.513338 seconds, 544960 images
# Loaded: 0.000038 seconds
#
#  8516: 0.240931, 0.267455 avg loss, 0.001000 rate, 1.467264 seconds, 545024 images
# Loaded: 0.000038 seconds
#
#  8517: 0.249195, 0.265629 avg loss, 0.001000 rate, 1.440253 seconds, 545088 images
# Loaded: 0.000050 seconds
#
#  8518: 0.200555, 0.259122 avg loss, 0.001000 rate, 1.457034 seconds, 545152 images
# Loaded: 0.000047 seconds
#
#  8519: 0.150693, 0.248279 avg loss, 0.001000 rate, 1.448503 seconds, 545216 images
# Loaded: 0.000037 seconds
#
#  8520: 0.242646, 0.247716 avg loss, 0.001000 rate, 1.477241 seconds, 545280 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.649986 seconds
#
#  8521: 0.269572, 0.249901 avg loss, 0.001000 rate, 1.032584 seconds, 545344 images
# Loaded: 0.000033 seconds
#
#  8522: 0.255488, 0.250460 avg loss, 0.001000 rate, 1.054605 seconds, 545408 images
# Loaded: 0.000041 seconds
#
#  8523: 0.213531, 0.246767 avg loss, 0.001000 rate, 1.057629 seconds, 545472 images
# Loaded: 0.000030 seconds
#
#  8524: 0.182975, 0.240388 avg loss, 0.001000 rate, 1.064099 seconds, 545536 images
# Loaded: 0.000036 seconds
#
#  8525: 0.130501, 0.229399 avg loss, 0.001000 rate, 1.040116 seconds, 545600 images
# Loaded: 0.000034 seconds
#
#  8526: 0.226090, 0.229068 avg loss, 0.001000 rate, 1.076436 seconds, 545664 images
# Loaded: 0.000041 seconds
#
#  8527: 0.210201, 0.227181 avg loss, 0.001000 rate, 1.030955 seconds, 545728 images
# Loaded: 0.000035 seconds
#
#  8528: 0.191600, 0.223623 avg loss, 0.001000 rate, 1.033430 seconds, 545792 images
# Loaded: 0.000045 seconds
#
#  8529: 0.248553, 0.226116 avg loss, 0.001000 rate, 1.052666 seconds, 545856 images
# Loaded: 0.000037 seconds
#
#  8530: 0.179918, 0.221496 avg loss, 0.001000 rate, 1.059961 seconds, 545920 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.506480 seconds
#
#  8531: 0.181802, 0.217527 avg loss, 0.001000 rate, 0.668509 seconds, 545984 images
# Loaded: 0.036944 seconds
#
#  8532: 0.222808, 0.218055 avg loss, 0.001000 rate, 0.671632 seconds, 546048 images
# Loaded: 0.025076 seconds
#
#  8533: 0.170596, 0.213309 avg loss, 0.001000 rate, 0.658175 seconds, 546112 images
# Loaded: 0.012603 seconds
#
#  8534: 0.115191, 0.203497 avg loss, 0.001000 rate, 0.659523 seconds, 546176 images
# Loaded: 0.024014 seconds
#
#  8535: 0.213561, 0.204504 avg loss, 0.001000 rate, 0.658644 seconds, 546240 images
# Loaded: 0.031673 seconds
#
#  8536: 0.139415, 0.197995 avg loss, 0.001000 rate, 0.715090 seconds, 546304 images
# Loaded: 0.000036 seconds
#
#  8537: 0.174462, 0.195642 avg loss, 0.001000 rate, 0.671332 seconds, 546368 images
# Loaded: 0.006542 seconds
#
#  8538: 0.185404, 0.194618 avg loss, 0.001000 rate, 0.713041 seconds, 546432 images
# Loaded: 0.000034 seconds
#
#  8539: 0.197161, 0.194872 avg loss, 0.001000 rate, 0.760407 seconds, 546496 images
# Loaded: 0.000032 seconds
#
#  8540: 0.215839, 0.196969 avg loss, 0.001000 rate, 0.669357 seconds, 546560 images
# Resizing
# 416 x 416
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.537604 seconds
#
#  8541: 0.157361, 0.193008 avg loss, 0.001000 rate, 0.828406 seconds, 546624 images
# Loaded: 0.000035 seconds
#
#  8542: 0.118423, 0.185550 avg loss, 0.001000 rate, 0.837567 seconds, 546688 images
# Loaded: 0.000035 seconds
#
#  8543: 0.115312, 0.178526 avg loss, 0.001000 rate, 0.860204 seconds, 546752 images
# Loaded: 0.000034 seconds
#
#  8544: 0.123083, 0.172981 avg loss, 0.001000 rate, 0.841078 seconds, 546816 images
# Loaded: 0.000036 seconds
#
#  8545: 0.137493, 0.169433 avg loss, 0.001000 rate, 0.834419 seconds, 546880 images
# Loaded: 0.000039 seconds
#
#  8546: 0.099926, 0.162482 avg loss, 0.001000 rate, 0.846541 seconds, 546944 images
# Loaded: 0.000035 seconds
#
#  8547: 0.158808, 0.162114 avg loss, 0.001000 rate, 0.835487 seconds, 547008 images
# Loaded: 0.000035 seconds
#
#  8548: 0.119014, 0.157804 avg loss, 0.001000 rate, 0.838656 seconds, 547072 images
# Loaded: 0.000026 seconds
#
#  8549: 0.151494, 0.157173 avg loss, 0.001000 rate, 0.847545 seconds, 547136 images
# Loaded: 0.000035 seconds
#
#  8550: 0.168664, 0.158323 avg loss, 0.001000 rate, 0.843195 seconds, 547200 images
# Resizing
# 512 x 512
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.603140 seconds
#
#  8551: 0.174217, 0.159912 avg loss, 0.001000 rate, 1.254573 seconds, 547264 images
# Loaded: 0.000039 seconds
#
#  8552: 0.114753, 0.155396 avg loss, 0.001000 rate, 1.205634 seconds, 547328 images
# Loaded: 0.000039 seconds
#
#  8553: 0.152722, 0.155129 avg loss, 0.001000 rate, 1.237290 seconds, 547392 images
# Loaded: 0.000032 seconds
#
#  8554: 0.112144, 0.150830 avg loss, 0.001000 rate, 1.223883 seconds, 547456 images
# Loaded: 0.000040 seconds
#
#  8555: 0.147576, 0.150505 avg loss, 0.001000 rate, 1.248977 seconds, 547520 images
# Loaded: 0.000038 seconds
#
#  8556: 0.222298, 0.157684 avg loss, 0.001000 rate, 1.243763 seconds, 547584 images
# Loaded: 0.000040 seconds
#
#  8557: 0.122114, 0.154127 avg loss, 0.001000 rate, 1.208397 seconds, 547648 images
# Loaded: 0.000037 seconds
#
#  8558: 0.120542, 0.150769 avg loss, 0.001000 rate, 1.264317 seconds, 547712 images
# Loaded: 0.000032 seconds
#
#  8559: 0.183127, 0.154004 avg loss, 0.001000 rate, 1.250878 seconds, 547776 images
# Loaded: 0.000036 seconds
#
#  8560: 0.178664, 0.156470 avg loss, 0.001000 rate, 1.235167 seconds, 547840 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.632131 seconds
#
#  8561: 0.125018, 0.153325 avg loss, 0.001000 rate, 1.056393 seconds, 547904 images
# Loaded: 0.000061 seconds
#
#  8562: 0.141037, 0.152096 avg loss, 0.001000 rate, 1.078598 seconds, 547968 images
# Loaded: 0.000051 seconds
#
#  8563: 0.126179, 0.149504 avg loss, 0.001000 rate, 1.086139 seconds, 548032 images
# Loaded: 0.000040 seconds
#
#  8564: 0.106224, 0.145176 avg loss, 0.001000 rate, 1.063593 seconds, 548096 images
# Loaded: 0.000038 seconds
#
#  8565: 0.107774, 0.141436 avg loss, 0.001000 rate, 1.058245 seconds, 548160 images
# Loaded: 0.000036 seconds
#
#  8566: 0.155927, 0.142885 avg loss, 0.001000 rate, 1.090465 seconds, 548224 images
# Loaded: 0.000040 seconds
#
#  8567: 0.131706, 0.141767 avg loss, 0.001000 rate, 1.054690 seconds, 548288 images
# Loaded: 0.000038 seconds
#
#  8568: 0.178355, 0.145426 avg loss, 0.001000 rate, 1.070256 seconds, 548352 images
# Loaded: 0.000038 seconds
#
#  8569: 0.117669, 0.142650 avg loss, 0.001000 rate, 1.089107 seconds, 548416 images
# Loaded: 0.000040 seconds
#
#  8570: 0.114074, 0.139793 avg loss, 0.001000 rate, 1.113617 seconds, 548480 images
# Resizing
# 384 x 384
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.580141 seconds
#
#  8571: 0.153474, 0.141161 avg loss, 0.001000 rate, 0.755350 seconds, 548544 images
# Loaded: 0.000034 seconds
#
#  8572: 0.205136, 0.147558 avg loss, 0.001000 rate, 0.768292 seconds, 548608 images
# Loaded: 0.000034 seconds
#
#  8573: 0.177632, 0.150566 avg loss, 0.001000 rate, 0.775695 seconds, 548672 images
# Loaded: 0.000037 seconds
#
#  8574: 0.142088, 0.149718 avg loss, 0.001000 rate, 0.762092 seconds, 548736 images
# Loaded: 0.000035 seconds
#
#  8575: 0.131485, 0.147895 avg loss, 0.001000 rate, 0.748527 seconds, 548800 images
# Loaded: 0.000033 seconds
#
#  8576: 0.153990, 0.148504 avg loss, 0.001000 rate, 0.760901 seconds, 548864 images
# Loaded: 0.000041 seconds
#
#  8577: 0.109687, 0.144622 avg loss, 0.001000 rate, 0.778067 seconds, 548928 images
# Loaded: 0.000039 seconds
#
#  8578: 0.099594, 0.140120 avg loss, 0.001000 rate, 0.770898 seconds, 548992 images
# Loaded: 0.000033 seconds
#
#  8579: 0.122676, 0.138375 avg loss, 0.001000 rate, 0.764542 seconds, 549056 images
# Loaded: 0.000038 seconds
#
#  8580: 0.190876, 0.143625 avg loss, 0.001000 rate, 0.806486 seconds, 549120 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.573296 seconds
#
#  8581: 0.167973, 0.146060 avg loss, 0.001000 rate, 1.039851 seconds, 549184 images
# Loaded: 0.000036 seconds
#
#  8582: 0.134255, 0.144879 avg loss, 0.001000 rate, 1.176190 seconds, 549248 images
# Loaded: 0.000040 seconds
#
#  8583: 0.121807, 0.142572 avg loss, 0.001000 rate, 1.132585 seconds, 549312 images
# Loaded: 0.000037 seconds
#
#  8584: 0.094199, 0.137735 avg loss, 0.001000 rate, 1.131796 seconds, 549376 images
# Loaded: 0.000041 seconds
#
#  8585: 0.113322, 0.135294 avg loss, 0.001000 rate, 1.143737 seconds, 549440 images
# Loaded: 0.000039 seconds
#
#  8586: 0.082745, 0.130039 avg loss, 0.001000 rate, 1.150978 seconds, 549504 images
# Loaded: 0.000043 seconds
#
#  8587: 0.132969, 0.130332 avg loss, 0.001000 rate, 1.122623 seconds, 549568 images
# Loaded: 0.000031 seconds
#
#  8588: 0.132700, 0.130568 avg loss, 0.001000 rate, 1.100417 seconds, 549632 images
# Loaded: 0.000033 seconds
#
#  8589: 0.124452, 0.129957 avg loss, 0.001000 rate, 1.116033 seconds, 549696 images
# Loaded: 0.000037 seconds
#
#  8590: 0.134215, 0.130383 avg loss, 0.001000 rate, 1.135757 seconds, 549760 images
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 52.43 MB
#  CUDA allocate done!
# Loaded: 0.616637 seconds
#
#  8591: 0.359682, 0.153313 avg loss, 0.001000 rate, 1.674042 seconds, 549824 images
# Loaded: 0.000041 seconds
#
#  8592: 0.295263, 0.167508 avg loss, 0.001000 rate, 1.667016 seconds, 549888 images
# Loaded: 0.000036 seconds
#
#  8593: 0.334863, 0.184243 avg loss, 0.001000 rate, 1.705201 seconds, 549952 images
# Loaded: 0.000037 seconds
#
#  8594: 0.243260, 0.190145 avg loss, 0.001000 rate, 1.681763 seconds, 550016 images
# Loaded: 0.000039 seconds
#
#  8595: 0.229164, 0.194047 avg loss, 0.001000 rate, 1.686904 seconds, 550080 images
# Loaded: 0.000044 seconds
#
#  8596: 0.219141, 0.196556 avg loss, 0.001000 rate, 1.682819 seconds, 550144 images
# Loaded: 0.000045 seconds
#
#  8597: 0.213290, 0.198230 avg loss, 0.001000 rate, 1.675340 seconds, 550208 images
# Loaded: 0.000038 seconds
#
#  8598: 0.283046, 0.206711 avg loss, 0.001000 rate, 1.681204 seconds, 550272 images
# Loaded: 0.000036 seconds
#
#  8599: 0.239087, 0.209949 avg loss, 0.001000 rate, 1.699170 seconds, 550336 images
# Loaded: 0.000033 seconds
